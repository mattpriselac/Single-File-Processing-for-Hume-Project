# %%
import pandas as pd
import os

# %%
slp = pd.read_csv('similarity_scores/s_l_p_similarity.csv', index_col=0)

# %%
slc = pd.read_csv('similarity_scores/s_l_c_similarity.csv', index_col=0)

# %%
slc['Literature'].sort_values().plot.bar()

# %%
slp['Literature'].sort_values().plot.bar()

# %%
alp = pd.read_csv('similarity_scores/a_l_p_similarity.csv', index_col=0)

# %%
alp['Literature'].sort_values().plot.bar()

# %%
alc = pd.read_csv('similarity_scores/a_l_c_similarity.csv', index_col=0)

# %%
alc['Literature'].sort_values().plot.bar()
